# %% [markdown]
# # DQN Approach

# %% [markdown]
# ## 0. Import the necessary packages

# %%
import math
import random
import matplotlib
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# if GPU is to be used
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# if metal is to be used
# device = torch.device("metal" if torch.cuda.is_available() else "cpu")

if torch.backends.mps.is_available():
    mps_device = torch.device("mps")
    x = torch.ones(1, device=mps_device)
    print (x)
else:
    print ("MPS device not found.")
# Out:
# tensor([1.], device='mps:0')

# %%
from actor_critic_simulation.real_environment import Environment

# %% [markdown]
# ## 1. Creating the architecture of the Q-Network and Agent

# %%
class DQN(nn.Module):

    def __init__(self, state_size, action_size, seed, fc1_units=128, fc2_units=128):
        super(DQN, self).__init__()
        self.seed = torch.manual_seed(seed)
        self.fc1 = nn.Linear(state_size, fc1_units)
        self.fc2 = nn.Linear(fc1_units, fc2_units)
        self.fc3 = nn.Linear(fc2_units, action_size)

    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

# %%
class ReplayBuffer:
    def __init__(self, action_size, buffer_size, batch_size, seed):
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)  
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
    
    def add(self, state, action, reward, next_state, done):
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)
    
    def sample(self):
        experiences = random.sample(self.memory, k=self.batch_size)

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)
  
        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        return len(self.memory)

# %%
class Agent():
    def __init__(self, state_size, action_size, dqn_type='DQN', replay_memory_size=1e5, batch_size=32, gamma=0.99,
    	learning_rate=1e-3, target_tau=2e-3, update_rate=4, seed=0):

        self.dqn_type = dqn_type
        self.state_size = state_size
        self.action_size = action_size
        self.buffer_size = int(replay_memory_size)
        self.batch_size = batch_size
        self.gamma = gamma
        self.learn_rate = learning_rate
        self.tau = target_tau
        self.update_rate = update_rate
        self.seed = random.seed(seed)

        self.network = DQN(state_size, action_size, seed).to(device)
        self.target_network = DQN(state_size, action_size, seed).to(device)
        self.optimizer = optim.Adam(self.network.parameters(), lr=self.learn_rate)

        # Replay memory
        self.memory = ReplayBuffer(action_size, self.buffer_size, self.batch_size, seed)

        # Initialize time step (for updating every UPDATE_EVERY steps)
        self.t_step = 0

    def step(self, state, action, reward, next_state, done):
        # Save experience in replay memory
        self.memory.add(state, action, reward, next_state, done)
        
        # Learn every UPDATE_EVERY time steps.
        self.t_step = (self.t_step + 1) % self.update_rate
        if self.t_step == 0:
            # If enough samples are available in memory, get random subset and learn
            if len(self.memory) > self.batch_size:
                experiences = self.memory.sample()
                self.learn(experiences, self.gamma)

    def act(self, state, eps=0.0):

        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        self.network.eval()
        with torch.no_grad():
            action_values = self.network(state)
        self.network.train()

        # Epsilon-greedy action selection
        if random.random() > eps:
            return np.argmax(action_values.cpu().data.numpy())
        else:
            return random.choice(np.arange(self.action_size))
        
	########################################################
    # LEARN() method
    # Update value parameters using given batch of experience tuples.
    def learn(self, experiences, gamma, DQN=True):
        states, actions, rewards, next_states, dones = experiences

        # Get Q values from current observations (s, a) using model nextwork
        Qsa = self.network(states).gather(1, actions)

        if (self.dqn_type == 'DDQN'):
        #Double DQN
            Qsa_prime_actions = self.network(next_states).detach().max(1)[1].unsqueeze(1)
            Qsa_prime_targets = self.target_network(next_states)[Qsa_prime_actions].unsqueeze(1)

        else:
        #Regular (Vanilla) DQN
            Qsa_prime_target_values = self.target_network(next_states).detach()
            Qsa_prime_targets = Qsa_prime_target_values.max(1)[0].unsqueeze(1)        

        
        # Compute Q targets for current states 
        Qsa_targets = rewards + (gamma * Qsa_prime_targets * (1 - dones))
        
        # Compute loss (error)
        loss = F.mse_loss(Qsa, Qsa_targets)

        # Minimize the loss
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        # ------------------- update target network ------------------- #
        self.soft_update(self.network, self.target_network, self.tau)


    ########################################################
    def soft_update(self, local_model, target_model, tau):

        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau*local_param.data + (1.0-tau)*target_param.data)

# %% [markdown]
# ## 2. Traininig the agent using Deep Q-Learning

# %%
import time

num_episodes=10000
epsilon=1.0
epsilon_min=0.05
epsilon_decay=0.99
scores = []
scores_average_window = 10      
solved_score = 14     

number_of_units = 5
n_actions = 5          

action_size = 5**5

env = Environment()
# env = Environment.from_simulation_session(agent)

state_size = env.reset().shape[0]

agent = Agent(state_size=state_size, action_size=action_size, dqn_type='DQN', batch_size=32, gamma=0.99,)


# loop from num_episodes
for i_episode in range(1, num_episodes+1):
    
    reward_episode = []
    state = env.reset()     
    # state = env.get_state()
    # print(f"state: {state}")
    # print(f"env_info: {env_info}")
    
    # set the initial episode score to zero.
    score = 0

    while True:
        # determine epsilon-greedy action from current sate
        action = agent.act(state, epsilon)         
        # print(f"\naction: {action}")    

        # send the action to the environment and receive resultant environment information
        state, reward, done, ending = env.step(
            action=int(action),
            number_of_units=number_of_units,
            number_of_actions_per_unit=n_actions,)    

        # next_state = env_info.vector_observations[0]   # get the next state
        next_state = state
        
        # agent.learn(state, action, reward, next_state, done)
        # reward = env_info.rewards[0]   
        reward_episode.append(reward)
        # done = env_info.local_done[0]                  # see if episode has finished

        #Send (S, A, R, S') info to the DQN agent for a neural network update
        agent.step(state, action, reward, next_state, done)

        # set new state to current state for determining next action
        state = next_state

        # Update episode score
        score += reward

        # If unity indicates that episode is done, 
        # then exit episode loop, to begin new episode
        if done:
            break

    # Calculate mean score over last 100 episodes 
    # Mean score is calculated over current episodes until i_episode > 100
    scores.append(score)
    average_score = np.mean(scores[i_episode-min(i_episode,scores_average_window):i_episode+1])

    # Decrease epsilon for epsilon-greedy policy by decay rate
    # Use max method to make sure epsilon doesn't decrease below epsilon_min
    epsilon = max(epsilon_min, epsilon_decay*epsilon)

    # (Over-) Print current average score
    print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, average_score), end="")

    # Print average score every scores_average_window episodes
    if i_episode % scores_average_window == 0:
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, average_score))
    
    # Check to see if the task is solved (i.e,. avearge_score > solved_score). 
    # If yes, save the network weights and scores and end training.
    if average_score >= solved_score:
        print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode, average_score))

        # Save trained neural network weights
        timestr = time.strftime("%Y%m%d-%H%M%S")
        nn_filename = "dqnAgent_Trained_Model_" + timestr + ".pth"
        torch.save(agent.network.state_dict(), nn_filename)

        # Save the recorded Scores data
        scores_filename = "dqnAgent_scores_" + timestr + ".csv"
        np.savetxt(scores_filename, scores, delimiter=",")
        break
# Out:
# Episode 5	Average Score: -680000.00
# /Users/maksymleshchenko/Data Science/University/War games/war_games/apps/actor_critic_simulation/real_environment.py:26: RuntimeWarning: invalid value encountered in scalar divide
#   avg_dist = np.sum(pairwise_distances) / (num_points * (num_points - 1))
# Episode 10	Average Score: -712550.00
# Episode 20	Average Score: -743150.00
# Episode 30	Average Score: -644350.00
# Episode 40	Average Score: -674100.00
# Episode 50	Average Score: -673350.00
# Episode 60	Average Score: -594300.00
# Episode 70	Average Score: -695100.00
# Episode 80	Average Score: -637900.00
# Episode 90	Average Score: -710500.00
# Episode 100	Average Score: -613350.00
# Episode 110	Average Score: -550700.00
# Episode 120	Average Score: -600300.00
# Episode 130	Average Score: -508300.00
# Episode 140	Average Score: -593800.00
# Episode 150	Average Score: -670300.00
# Episode 160	Average Score: -549200.00
# Episode 170	Average Score: -484800.00
# Episode 180	Average Score: -478450.00
# Episode 190	Average Score: -533150.00
# Episode 200	Average Score: -485100.00
# Episode 210	Average Score: -470000.00
# Episode 220	Average Score: -537050.00
# Episode 230	Average Score: -553450.00
# Episode 240	Average Score: -463100.00
# Episode 250	Average Score: -488150.00
# Episode 260	Average Score: -498500.00
# Episode 270	Average Score: -600800.00
# Episode 280	Average Score: -516950.00
# Episode 290	Average Score: -458300.00
# Episode 300	Average Score: -475300.00
# Episode 310	Average Score: -613750.00
# Episode 320	Average Score: -673550.00
# Episode 330	Average Score: -536700.00
# Episode 340	Average Score: -472750.00
# Episode 350	Average Score: -540650.00
# Episode 360	Average Score: -499700.00
# Episode 370	Average Score: -695750.00
# Episode 380	Average Score: -634300.00
# Episode 390	Average Score: -513050.00
# Episode 400	Average Score: -605100.00
# Episode 410	Average Score: -713100.00
# Episode 420	Average Score: -731000.00
# Episode 430	Average Score: -476250.00
# Episode 440	Average Score: -731350.00
# Episode 450	Average Score: -628950.00
# Episode 460	Average Score: -725250.00
# Episode 470	Average Score: -892300.00
# Episode 480	Average Score: -864600.000
# Episode 490	Average Score: -584200.00
# Episode 500	Average Score: -483100.00
# Episode 510	Average Score: -520650.00
# Episode 520	Average Score: -822800.00
# Episode 530	Average Score: -643400.00
# Episode 540	Average Score: -713050.00
# Episode 550	Average Score: -609450.00
# Episode 560	Average Score: -536300.00
# Episode 570	Average Score: -587600.00
# Episode 580	Average Score: -472950.00
# Episode 590	Average Score: -486450.00
# Episode 600	Average Score: -578100.00
# Episode 610	Average Score: -420800.00
# Episode 620	Average Score: -453700.00
# Episode 630	Average Score: -508250.00
# Episode 640	Average Score: -424800.00
# Episode 650	Average Score: -442200.00
# Episode 660	Average Score: -472300.00
# Episode 670	Average Score: -388150.00
# Episode 680	Average Score: -401950.00
# Episode 690	Average Score: -525450.00
# Episode 700	Average Score: -432350.00
# Episode 710	Average Score: -429900.00
# Episode 720	Average Score: -534400.00
# Episode 730	Average Score: -412200.00
# Episode 740	Average Score: -440400.00
# Episode 750	Average Score: -397850.00
# Episode 760	Average Score: -425900.00
# Episode 770	Average Score: -445900.00
# Episode 780	Average Score: -436950.00
# Episode 790	Average Score: -410450.00
# Episode 800	Average Score: -436900.00
# Episode 810	Average Score: -504550.00
# Episode 820	Average Score: -451550.00
# Episode 830	Average Score: -646800.00
# Episode 840	Average Score: -433900.00
# Episode 850	Average Score: -490200.00
# Episode 860	Average Score: -439800.00
# Episode 870	Average Score: -474300.00
# Episode 880	Average Score: -450750.00
# Episode 890	Average Score: -515000.00
# Episode 900	Average Score: -457600.00
# Episode 910	Average Score: -488400.00
# Episode 920	Average Score: -471400.00
# Episode 930	Average Score: -522250.00
# Episode 940	Average Score: -480800.00
# Episode 950	Average Score: -447800.00
# Episode 960	Average Score: -443100.00
# Episode 970	Average Score: -608850.00
# Episode 980	Average Score: -579500.00
# Episode 990	Average Score: -469700.00
# Episode 1000	Average Score: -444950.00
# Episode 1010	Average Score: -523450.00
# Episode 1020	Average Score: -446350.00
# Episode 1030	Average Score: -463750.00
# Episode 1040	Average Score: -492900.00
# Episode 1050	Average Score: -530000.00
# Episode 1060	Average Score: -514900.00
# Episode 1070	Average Score: -607050.00
# Episode 1080	Average Score: -589250.00
# Episode 1090	Average Score: -674650.00
# Episode 1100	Average Score: -624750.00
# Episode 1110	Average Score: -653800.00
# Episode 1120	Average Score: -606050.00
# Episode 1130	Average Score: -638900.00
# Episode 1140	Average Score: -704700.00
# Episode 1150	Average Score: -711400.00
# Episode 1160	Average Score: -533000.00
# Episode 1170	Average Score: -747850.00
# Episode 1180	Average Score: -595150.00
# Episode 1190	Average Score: -965950.00
# Episode 1200	Average Score: -813400.000
# Episode 1210	Average Score: -558800.00
# Episode 1220	Average Score: -641200.00
# Episode 1230	Average Score: -556150.00
# Episode 1240	Average Score: -659300.00
# Episode 1250	Average Score: -696100.00
# Episode 1260	Average Score: -504650.00
# Episode 1270	Average Score: -480100.00
# Episode 1280	Average Score: -669750.00
# Episode 1290	Average Score: -986100.000
# Episode 1300	Average Score: -544300.00
# Episode 1310	Average Score: -833950.00
# Episode 1320	Average Score: -821850.00
# Episode 1330	Average Score: -690300.00
# Episode 1340	Average Score: -517600.00
# Episode 1350	Average Score: -806250.00
# Episode 1360	Average Score: -469200.00
# Episode 1370	Average Score: -570950.00
# Episode 1380	Average Score: -603000.00
# Episode 1390	Average Score: -559200.00
# Episode 1400	Average Score: -860700.00
# Episode 1410	Average Score: -781250.00
# Episode 1420	Average Score: -566650.00
# Episode 1430	Average Score: -850550.00
# Episode 1440	Average Score: -499100.00
# Episode 1450	Average Score: -720900.00
# Episode 1460	Average Score: -887050.00
# Episode 1470	Average Score: -827250.00
# Episode 1480	Average Score: -753500.00
# Episode 1490	Average Score: -816850.00
# Episode 1500	Average Score: -638600.00
# Episode 1510	Average Score: -724250.00
# Episode 1520	Average Score: -652050.00
# Episode 1530	Average Score: -694950.00
# Episode 1540	Average Score: -553650.00
# Episode 1550	Average Score: -475150.00
# Episode 1560	Average Score: -891850.00
# Episode 1570	Average Score: -628550.00
# Episode 1580	Average Score: -876800.00
# Episode 1590	Average Score: -680800.00
# Episode 1600	Average Score: -609600.00
# Episode 1610	Average Score: -551150.00
# Episode 1620	Average Score: -753650.00
# Episode 1630	Average Score: -563200.00
# Episode 1640	Average Score: -945100.00
# Episode 1650	Average Score: -830200.00
# Episode 1660	Average Score: -483250.00
# Episode 1670	Average Score: -656500.00
# Episode 1680	Average Score: -669750.00
# Episode 1690	Average Score: -1002300.00
# Episode 1700	Average Score: -623400.00
# Episode 1710	Average Score: -847700.00
# Episode 1720	Average Score: -751150.00
# Episode 1730	Average Score: -695750.00
# Episode 1740	Average Score: -1275400.00
# Episode 1750	Average Score: -784750.000
# Episode 1760	Average Score: -622150.00
# Episode 1770	Average Score: -494400.00
# Episode 1780	Average Score: -793700.00
# Episode 1790	Average Score: -996200.000
# Episode 1800	Average Score: -519600.000
# Episode 1810	Average Score: -534300.00
# Episode 1820	Average Score: -550050.00
# Episode 1830	Average Score: -624900.00
# Episode 1840	Average Score: -550300.00
# Episode 1850	Average Score: -827650.00
# Episode 1860	Average Score: -584100.00
# Episode 1870	Average Score: -802600.00
# Episode 1880	Average Score: -647850.00
# Episode 1890	Average Score: -755000.00
# Episode 1900	Average Score: -839150.00
# Episode 1910	Average Score: -770950.00
# Episode 1920	Average Score: -845550.00
# Episode 1930	Average Score: -483300.00
# Episode 1940	Average Score: -465700.00
# Episode 1950	Average Score: -556700.00
# Episode 1960	Average Score: -541350.00
# Episode 1970	Average Score: -591200.00
# Episode 1980	Average Score: -561300.00
# Episode 1990	Average Score: -872250.00
# Episode 2000	Average Score: -700550.00
# Episode 2010	Average Score: -595550.00
# Episode 2020	Average Score: -554250.00
# Episode 2030	Average Score: -555400.00
# Episode 2040	Average Score: -661500.00
# Episode 2050	Average Score: -832600.00
# Episode 2060	Average Score: -773300.00
# Episode 2070	Average Score: -500900.00
# Episode 2080	Average Score: -776600.00
# Episode 2090	Average Score: -818400.00
# Episode 2100	Average Score: -1026650.00
# Episode 2110	Average Score: -755850.000
# Episode 2120	Average Score: -571550.00
# Episode 2130	Average Score: -510350.00
# Episode 2140	Average Score: -575450.00
# Episode 2150	Average Score: -649750.00
# Episode 2160	Average Score: -696150.00
# Episode 2170	Average Score: -658400.00
# Episode 2180	Average Score: -672850.00
# Episode 2190	Average Score: -741000.00
# Episode 2200	Average Score: -623350.00
# Episode 2210	Average Score: -555750.00
# Episode 2220	Average Score: -486950.00
# Episode 2230	Average Score: -549250.00
# Episode 2240	Average Score: -718000.00
# Episode 2250	Average Score: -448500.00
# Episode 2260	Average Score: -497000.00
# Episode 2270	Average Score: -602000.00
# Episode 2280	Average Score: -626750.00
# Episode 2290	Average Score: -497650.00
# Episode 2300	Average Score: -853950.00
# Episode 2310	Average Score: -763550.000
# Episode 2320	Average Score: -594150.00
# Episode 2330	Average Score: -741450.00
# Episode 2340	Average Score: -487950.00
# Episode 2350	Average Score: -721850.00
# Episode 2360	Average Score: -681300.00
# Episode 2370	Average Score: -958300.00
# Episode 2380	Average Score: -460300.00
# Episode 2390	Average Score: -473600.00
# Episode 2396	Average Score: -469250.00enemy killed
# Episode 2400	Average Score: -445100.00
# Episode 2410	Average Score: -506600.00
# Episode 2420	Average Score: -732500.00
# Episode 2430	Average Score: -604350.00
# Episode 2440	Average Score: -716950.00
# Episode 2450	Average Score: -594150.00
# Episode 2460	Average Score: -486400.00
# Episode 2470	Average Score: -581500.00
# Episode 2480	Average Score: -509950.00
# Episode 2490	Average Score: -468600.00
# Episode 2500	Average Score: -512400.00
# Episode 2510	Average Score: -482800.00
# Episode 2520	Average Score: -687950.00
# Episode 2530	Average Score: -512600.00
# Episode 2540	Average Score: -489950.00
# Episode 2550	Average Score: -630800.00
# Episode 2560	Average Score: -718800.00
# Episode 2570	Average Score: -665250.00
# Episode 2580	Average Score: -720150.00
# Episode 2590	Average Score: -617400.00
# Episode 2600	Average Score: -456050.00
# Episode 2610	Average Score: -544550.00
# Episode 2620	Average Score: -513600.00
# Episode 2630	Average Score: -684600.00
# Episode 2640	Average Score: -635700.00
# Episode 2650	Average Score: -471750.00
# Episode 2660	Average Score: -644400.00
# Episode 2670	Average Score: -888050.00
# Episode 2680	Average Score: -546400.00
# Episode 2690	Average Score: -641300.00
# Episode 2700	Average Score: -615800.00
# Episode 2710	Average Score: -574000.00
# Episode 2720	Average Score: -690450.00
# Episode 2730	Average Score: -526600.00
# Episode 2740	Average Score: -534900.00
# Episode 2750	Average Score: -571350.00
# Episode 2760	Average Score: -498050.00
# Episode 2770	Average Score: -514450.00
# Episode 2780	Average Score: -591850.00
# Episode 2790	Average Score: -512550.00
# Episode 2800	Average Score: -733350.00
# Episode 2810	Average Score: -471500.00
# Episode 2820	Average Score: -505750.00
# Episode 2830	Average Score: -641750.00
# Episode 2840	Average Score: -491100.00
# Episode 2850	Average Score: -713700.00
# Episode 2860	Average Score: -713450.00
# Episode 2870	Average Score: -450800.00
# Episode 2880	Average Score: -458300.00
# Episode 2890	Average Score: -662500.00
# Episode 2900	Average Score: -572700.00
# Episode 2910	Average Score: -475950.00
# Episode 2920	Average Score: -466700.00
# Episode 2930	Average Score: -447200.00
# Episode 2940	Average Score: -765800.00
# Episode 2950	Average Score: -523800.00
# Episode 2960	Average Score: -460700.00
# Episode 2970	Average Score: -762600.00
# Episode 2980	Average Score: -452050.00
# Episode 2990	Average Score: -550100.00
# Episode 3000	Average Score: -462150.00
# Episode 3010	Average Score: -481300.00
# Episode 3020	Average Score: -763650.00
# Episode 3030	Average Score: -621400.00
# Episode 3040	Average Score: -438700.00
# Episode 3050	Average Score: -523400.00
# Episode 3060	Average Score: -620100.00
# Episode 3070	Average Score: -579100.00
# Episode 3080	Average Score: -486150.00
# Episode 3090	Average Score: -648550.00
# Episode 3100	Average Score: -523250.00
# Episode 3110	Average Score: -579000.00
# Episode 3120	Average Score: -488300.00
# Episode 3130	Average Score: -536400.00
# Episode 3140	Average Score: -526350.00
# Episode 3150	Average Score: -783450.00
# Episode 3160	Average Score: -626200.00
# Episode 3170	Average Score: -731300.00
# Episode 3180	Average Score: -509400.00
# Episode 3190	Average Score: -599500.00
# Episode 3200	Average Score: -730450.00
# Episode 3210	Average Score: -459200.00
# Episode 3220	Average Score: -513350.00
# Episode 3230	Average Score: -591350.00
# Episode 3240	Average Score: -528950.00
# Episode 3250	Average Score: -499150.00
# Episode 3260	Average Score: -510200.00
# Episode 3270	Average Score: -488300.00
# Episode 3280	Average Score: -542700.00
# Episode 3290	Average Score: -557600.00
# Episode 3300	Average Score: -765950.00
# Episode 3310	Average Score: -588700.00
# Episode 3320	Average Score: -621600.00
# Episode 3330	Average Score: -552650.00
# Episode 3340	Average Score: -528250.00
# Episode 3350	Average Score: -546700.00
# Episode 3360	Average Score: -863600.00
# Episode 3370	Average Score: -615800.00
# Episode 3380	Average Score: -669550.00
# Episode 3387	Average Score: -802100.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 56
#      52 reward_episode.append(reward)
#      53 # done = env_info.local_done[0]                  # see if episode has finished
#      54
#      55 #Send (S, A, R, S') info to the DQN agent for a neural network update
# ---> 56 agent.step(state, action, reward, next_state, done)
#      58 # set new state to current state for determining next action
#      59 state = next_state
#
# Cell In[64], line 70, in Agent.step(self, state, action, reward, next_state, done)
#      68 if len(self.memory) > self.batch_size:
#      69     experiences = self.memory.sample()
# ---> 70     self.learn(experiences, self.gamma)
#
# Cell In[64], line 140, in Agent.learn(self, experiences, gamma, DQN)
#     138 # Minimize the loss
#     139 self.optimizer.zero_grad()
# --> 140 loss.backward()
#     141 self.optimizer.step()
#     143 # ------------------- update target network ------------------- #
#
# File ~/anaconda3/envs/datascience/lib/python3.11/site-packages/torch/_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File ~/anaconda3/envs/datascience/lib/python3.11/site-packages/torch/autograd/__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %% [markdown]
# Agent didn't converge
